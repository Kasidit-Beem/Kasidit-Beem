# %% [markdown]
# <a href="https://colab.research.google.com/github/Kasidit-Beem/Kasidit-Beem/blob/main/Higgs_tutorial_edit_comptl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hi.
#
# This is a neural network tutorial designed to make sure you know how to create and evaluate your neural network. In this tutorial, we will be using a HIGGS dataset involving theoretical heavy Higgs bosons via Monte-Carlo simulated collision events. Everything you are seeing in this tutorial does not involve any real data taking at CERN or anywhere else, so rest assured. We are not looking for new particles at the LHC. Not yet, at least.
#
# This tutorial will be based on the HIGGS dataset available here: https://archive.ics.uci.edu/ml/datasets/HIGGS#, which is used in the following work:
# P. Baldi, P. Sadowski, and D. Whiteson, Nat. Commun. 5 (2014) 4308
#
# If you get stuck, you know how to reach me. Have fun!

# %% [markdown]
# Let's import some libraries first. I am importing Keras layers directly, but if you come from this tutorial on TensorFlow website https://www.tensorflow.org/tutorials/keras/classification, I have already imported the necessary libraries for you too.

# %%
import tensorflow as tf
import numpy as np
import keras
from keras.layers import Input, Dense, Dropout
from keras.models import Model
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Now download and unzip the HIGGS dataset. This dataset is generated with Monte-Carlo simulations, and it contains signal processes which generates Higgs, and background processes which does not.

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00280/HIGGS.csv.gz
# !gunzip HIGGS.csv.gz
# Out:
# --2021-11-08 08:57:47--  https://archive.ics.uci.edu/ml/machine-learning-databases/00280/HIGGS.csv.gz
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2816407858 (2.6G) [application/x-httpd-php]
# Saving to: ‘HIGGS.csv.gz’
#
# HIGGS.csv.gz        100%[===================>]   2.62G  36.9MB/s    in 37s
#
# 2021-11-08 08:58:25 (72.1 MB/s) - ‘HIGGS.csv.gz’ saved [2816407858/2816407858]

# %% [markdown]
# This is a large dataset of 11 million events, so it will take time.
#
# An exclamation mark `!` in front of the commands are shell commands that you can execute directly in Jupyter notebook. This example below shows what kind of files we have right now in the working directory. If you want to understand this further you need to know your way around bash shell, `wget`, and `gunzip`.

# %%
# !ls -l
# Out:
# total 4
# drwxr-xr-x 1 root root 4096 Oct  8 13:45 sample_data

# %% [markdown]
# Peeking into the `head` of the extracted CSV file...

# %%
# !head HIGGS.csv
# Out:
# 1.000000000000000000e+00,8.692932128906250000e-01,-6.350818276405334473e-01,2.256902605295181274e-01,3.274700641632080078e-01,-6.899932026863098145e-01,7.542022466659545898e-01,-2.485731393098831177e-01,-1.092063903808593750e+00,0.000000000000000000e+00,1.374992132186889648e+00,-6.536741852760314941e-01,9.303491115570068359e-01,1.107436060905456543e+00,1.138904333114624023e+00,-1.578198313713073730e+00,-1.046985387802124023e+00,0.000000000000000000e+00,6.579295396804809570e-01,-1.045456994324922562e-02,-4.576716944575309753e-02,3.101961374282836914e+00,1.353760004043579102e+00,9.795631170272827148e-01,9.780761599540710449e-01,9.200048446655273438e-01,7.216574549674987793e-01,9.887509346008300781e-01,8.766783475875854492e-01
# 1.000000000000000000e+00,9.075421094894409180e-01,3.291472792625427246e-01,3.594118654727935791e-01,1.497969865798950195e+00,-3.130095303058624268e-01,1.095530629158020020e+00,-5.575249195098876953e-01,-1.588229775428771973e+00,2.173076152801513672e+00,8.125811815261840820e-01,-2.136419266462326050e-01,1.271014571189880371e+00,2.214872121810913086e+00,4.999939501285552979e-01,-1.261431813240051270e+00,7.321561574935913086e-01,0.000000000000000000e+00,3.987008929252624512e-01,-1.138930082321166992e+00,-8.191101951524615288e-04,0.000000000000000000e+00,3.022198975086212158e-01,8.330481648445129395e-01,9.856996536254882812e-01,9.780983924865722656e-01,7.797321677207946777e-01,9.923557639122009277e-01,7.983425855636596680e-01
# 1.000000000000000000e+00,7.988347411155700684e-01,1.470638751983642578e+00,-1.635974764823913574e+00,4.537731707096099854e-01,4.256291687488555908e-01,1.104874610900878906e+00,1.282322287559509277e+00,1.381664276123046875e+00,0.000000000000000000e+00,8.517372012138366699e-01,1.540658950805664062e+00,-8.196895122528076172e-01,2.214872121810913086e+00,9.934899210929870605e-01,3.560801148414611816e-01,-2.087775468826293945e-01,2.548224449157714844e+00,1.256954550743103027e+00,1.128847599029541016e+00,9.004608392715454102e-01,0.000000000000000000e+00,9.097532629966735840e-01,1.108330488204956055e+00,9.856922030448913574e-01,9.513312578201293945e-01,8.032515048980712891e-01,8.659244179725646973e-01,7.801175713539123535e-01
# 0.000000000000000000e+00,1.344384789466857910e+00,-8.766260147094726562e-01,9.359127283096313477e-01,1.992050051689147949e+00,8.824543952941894531e-01,1.786065936088562012e+00,-1.646777749061584473e+00,-9.423825144767761230e-01,0.000000000000000000e+00,2.423264741897583008e+00,-6.760157942771911621e-01,7.361586689949035645e-01,2.214872121810913086e+00,1.298719763755798340e+00,-1.430738091468811035e+00,-3.646581768989562988e-01,0.000000000000000000e+00,7.453126907348632812e-01,-6.783788204193115234e-01,-1.360356330871582031e+00,0.000000000000000000e+00,9.466524720191955566e-01,1.028703689575195312e+00,9.986560940742492676e-01,7.282806038856506348e-01,8.692002296447753906e-01,1.026736497879028320e+00,9.579039812088012695e-01
# 1.000000000000000000e+00,1.105008959770202637e+00,3.213555514812469482e-01,1.522401213645935059e+00,8.828076124191284180e-01,-1.205349326133728027e+00,6.814661026000976562e-01,-1.070463895797729492e+00,-9.218706488609313965e-01,0.000000000000000000e+00,8.008721470832824707e-01,1.020974040031433105e+00,9.714065194129943848e-01,2.214872121810913086e+00,5.967612862586975098e-01,-3.502728641033172607e-01,6.311942934989929199e-01,0.000000000000000000e+00,4.799988865852355957e-01,-3.735655248165130615e-01,1.130406111478805542e-01,0.000000000000000000e+00,7.558564543724060059e-01,1.361057043075561523e+00,9.866096973419189453e-01,8.380846381187438965e-01,1.133295178413391113e+00,8.722448945045471191e-01,8.084865212440490723e-01
# 0.000000000000000000e+00,1.595839262008666992e+00,-6.078106760978698730e-01,7.074915803968906403e-03,1.818449616432189941e+00,-1.119059920310974121e-01,8.475499153137207031e-01,-5.664370059967041016e-01,1.581239342689514160e+00,2.173076152801513672e+00,7.554209828376770020e-01,6.431096196174621582e-01,1.426366806030273438e+00,0.000000000000000000e+00,9.216607809066772461e-01,-1.190432429313659668e+00,-1.615589022636413574e+00,0.000000000000000000e+00,6.511141061782836914e-01,-6.542269587516784668e-01,-1.274344921112060547e+00,3.101961374282836914e+00,8.237605690956115723e-01,9.381914138793945312e-01,9.717581868171691895e-01,7.891763448715209961e-01,4.305532872676849365e-01,9.613569378852844238e-01,9.578179121017456055e-01
# 1.000000000000000000e+00,4.093913435935974121e-01,-1.884683609008789062e+00,-1.027292013168334961e+00,1.672451734542846680e+00,-1.604598283767700195e+00,1.338014960289001465e+00,5.542744323611259460e-02,1.346588134765625000e-02,2.173076152801513672e+00,5.097832679748535156e-01,-1.038338065147399902e+00,7.078623175621032715e-01,0.000000000000000000e+00,7.469175457954406738e-01,-3.584651052951812744e-01,-1.646654248237609863e+00,0.000000000000000000e+00,3.670579791069030762e-01,6.949646025896072388e-02,1.377130270004272461e+00,3.101961374282836914e+00,8.694183826446533203e-01,1.222082972526550293e+00,1.000627398490905762e+00,5.450449585914611816e-01,6.986525058746337891e-01,9.773144721984863281e-01,8.287860751152038574e-01
# 1.000000000000000000e+00,9.338953495025634766e-01,6.291297078132629395e-01,5.275348424911499023e-01,2.380327433347702026e-01,-9.665691256523132324e-01,5.478111505508422852e-01,-5.943922698497772217e-02,-1.706866145133972168e+00,2.173076152801513672e+00,9.410027265548706055e-01,-2.653732776641845703e+00,-1.572199910879135132e-01,0.000000000000000000e+00,1.030370354652404785e+00,-1.755051016807556152e-01,5.230209231376647949e-01,2.548224449157714844e+00,1.373546600341796875e+00,1.291248083114624023e+00,-1.467454433441162109e+00,0.000000000000000000e+00,9.018372893333435059e-01,1.083671212196350098e+00,9.796960949897766113e-01,7.833003997802734375e-01,8.491951823234558105e-01,8.943563103675842285e-01,7.748793959617614746e-01
# 1.000000000000000000e+00,1.405143737792968750e+00,5.366026163101196289e-01,6.895543336868286133e-01,1.179567337036132812e+00,-1.100611537694931030e-01,3.202404975891113281e+00,-1.526960015296936035e+00,-1.576033473014831543e+00,0.000000000000000000e+00,2.931536912918090820e+00,5.673424601554870605e-01,-1.300333440303802490e-01,2.214872121810913086e+00,1.787122726440429688e+00,8.994985818862915039e-01,5.851513147354125977e-01,2.548224449157714844e+00,4.018652141094207764e-01,-1.512016952037811279e-01,1.163489103317260742e+00,0.000000000000000000e+00,1.667070508003234863e+00,4.039272785186767578e+00,1.175828456878662109e+00,1.045351743698120117e+00,1.542971968650817871e+00,3.534826755523681641e+00,2.740753889083862305e+00
# 1.000000000000000000e+00,1.176565527915954590e+00,1.041605025529861450e-01,1.397002458572387695e+00,4.797213077545166016e-01,2.655133903026580811e-01,1.135563015937805176e+00,1.534830927848815918e+00,-2.532912194728851318e-01,0.000000000000000000e+00,1.027246594429016113e+00,5.343157649040222168e-01,1.180022358894348145e+00,0.000000000000000000e+00,2.405661106109619141e+00,8.755676448345184326e-02,-9.765340685844421387e-01,2.548224449157714844e+00,1.250382542610168457e+00,2.685412168502807617e-01,5.303344726562500000e-01,0.000000000000000000e+00,8.331748843193054199e-01,7.739681005477905273e-01,9.857499599456787109e-01,1.103696346282958984e+00,8.491398692131042480e-01,9.371039867401123047e-01,8.123638033866882324e-01

# %% [markdown]
# Now we import data with pandas using the following command. I have written a quick code which will import the above CSV file into a nice pandas DataFrame format, so you don't have to do any kind of wetwork.
#
# Again, we are using a dataset of 11 million events, so it will take some time.

# %%
column_headers = ["signal", 'lepton_pT',
 'lepton_eta',
 'lepton_phi',
 'MET',
 'MET_phi',
 'jet1_pt','jet1_eta','jet1_phi','jet1_btag',
 'jet2_pt','jet2_eta','jet2_phi','jet2_btag',
 'jet3_pt','jet3_eta','jet3_phi','jet3_btag',
 'jet4_pt','jet4_eta','jet4_phi','jet4_btag',
 'm_jj',
 'm_jjj',
 'm_lv',
 'm_jlv',
 'm_bb',
 'm_wbb',
 'm_wwbb']
higgs_data = pd.read_csv("HIGGS.csv", names=column_headers)

# %% [markdown]
# Since pandas is a library that handles tabular data, you can have it output the table nicely like this.

# %%
higgs_data
# Out:
#           signal  lepton_pT  lepton_eta  ...      m_bb     m_wbb    m_wwbb
# 0            1.0   0.869293   -0.635082  ...  0.721657  0.988751  0.876678
# 1            1.0   0.907542    0.329147  ...  0.779732  0.992356  0.798343
# 2            1.0   0.798835    1.470639  ...  0.803252  0.865924  0.780118
# 3            0.0   1.344385   -0.876626  ...  0.869200  1.026736  0.957904
# 4            1.0   1.105009    0.321356  ...  1.133295  0.872245  0.808487
# ...          ...        ...         ...  ...       ...       ...       ...
# 10999995     1.0   1.159912    1.013847  ...  0.837004  0.860472  0.772484
# 10999996     1.0   0.618388   -1.012982  ...  0.891481  0.938490  0.865269
# 10999997     1.0   0.700559    0.774251  ...  1.888438  1.153766  0.931279
# 10999998     0.0   1.178030    0.117796  ...  0.339705  0.759070  0.719119
# 10999999     0.0   0.464477   -0.337047  ...  0.576084  0.541427  0.517420
#
# [11000000 rows x 29 columns]

# %% [markdown]
# The table above contains 11 million collision events generated from Monte-Carlo simulations. The first column tells us whether the event is a signal event (1) where a Higgs boson is generated, or a background event (0) where a Higgs boson is not generatedd. The next 21 columns are low-level variables: transverse momentum (pT), pseudorapidity (eta), polar angle in the transverse plane (phi), and b-tagging discriminators from several objects (leptons, particle jets, and neutrinos) in each event. The last 7 columns represent the invariant mass of each combination of objects, like two jets, three jets, one lepton plus one neutrino, and so on. Unfortunately, the data has been already normalised, so you didn't get to see what the distribution of jet pT actually looks like.
#
# The Higgs process that we are looking at is the process involving "new theoretical Higgs bosons", which subsequently decays into two W bosons and two b quarks. The background process, on the other hand, is a simple top-antitop quark pair production, which eventually decays into two W bosons and two b quarks, the same as in signal process. The idea is that we want to discriminate between those two processes by means of machine learning.
#
# Now here are some physics details. What you will be seeing right after each collision is the final state of particles, not the particles created right after proton-proton collision. Normally you will see some photons, leptons, particle jets, and sometimes there are some things missing. Those stuffs are the final state particles, and it can be caused by a chain of particle decays, initial or final state radiations, or it may be caused by another interaction occuring at the same time as the main collision (which we call pileup). Right after quarks are created, they cannot be free and must group up with other quarks and form hadrons, so you would not see quarks individually, but a stream of particle jets, or put simply, jets. As for neutrinos, usually detectors like CMS and ATLAS detectors cannot detect them, but you need to have net zero transverse momentum since you have a head-on collision. This is where missing transverse energy (MET) comes in.
#
# If you are interested about this dataset, have a look at this paper:
# P. Baldi, P. Sadowski, and D. Whiteson, Nat. Commun. 5 (2014) 4308

# %% [markdown]
# Now we are going to define the training and testing datasets. We want to do this quickly, so I will be using only 100k events each for training and testing datasets.

# %%
higgs_data_train = higgs_data[:100000]
higgs_data_validation = higgs_data[100000:200000]
higgs_data_test=higgs_data[200000:300000]

# %%
higgs_data_train
# Out:
#        signal  lepton_pT  lepton_eta  ...      m_bb     m_wbb    m_wwbb
# 0         1.0   0.869293   -0.635082  ...  0.721657  0.988751  0.876678
# 1         1.0   0.907542    0.329147  ...  0.779732  0.992356  0.798343
# 2         1.0   0.798835    1.470639  ...  0.803252  0.865924  0.780118
# 3         0.0   1.344385   -0.876626  ...  0.869200  1.026736  0.957904
# 4         1.0   1.105009    0.321356  ...  1.133295  0.872245  0.808487
# ...       ...        ...         ...  ...       ...       ...       ...
# 99995     0.0   1.541120   -0.948700  ...  0.971256  0.962689  0.914845
# 99996     1.0   0.957321   -0.759750  ...  0.840251  0.702825  0.642653
# 99997     1.0   0.878993   -1.687942  ...  0.911731  0.911673  0.805071
# 99998     0.0   1.090185    0.409987  ...  1.313143  1.096304  0.963150
# 99999     1.0   1.395078    0.143119  ...  1.098247  1.488028  1.466187
#
# [100000 rows x 29 columns]

# %% [markdown]
# Don't worry about class imbalance in training dataset for now. Our training and testing datasets have a good balance. Trust me, I have seen worse signal-background distribution than this.

# %%
higgs_data_train["signal"].value_counts()
# Out:
# 1.0    52834
# 0.0    47166
# Name: signal, dtype: int64

# %%
higgs_data_test["signal"].value_counts()
# Out:
# 1.0    52694
# 0.0    47306
# Name: signal, dtype: int64

# %%
higgs_data_validation["signal"].value_counts()
# Out:
# 1.0    52842
# 0.0    47158
# Name: signal, dtype: int64

# %% [markdown]
# Separating the data into features and labels one more time. The training and testing data is now in the form of a lovely numpy array, which you can plug in easily, just like in the tutorial.

# %%
x_train, y_train = higgs_data_train.to_numpy()[:, 1:], higgs_data_train.to_numpy()[:, 0]
x_vali,y_vali=higgs_data_validation.to_numpy()[:,1:],higgs_data_validation.to_numpy()[:,0]
x_test, y_test = higgs_data_test.to_numpy()[:, 1:], higgs_data_test.to_numpy()[:, 0]

# %%
x_train.shape, x_test.shape,x_vali.shape
# Out:
# ((100000, 28), (100000, 28), (100000, 28))

# %% [markdown]
# #**Time to get to work**.
#
# Your job is to design a neural network that takes in the input above and train them. Consult the tutorial if you get stuck. https://www.tensorflow.org/tutorials/keras/classification
#
# If you are still stuck or you have any technical problems, you know how to reach me.

# %% [markdown]
# **Beem** : First, let try different optimizer
#
# **1) SCG (learning rate=0.01)**

# %%
model1=tf.keras.Sequential([keras.Input(shape=28),
                            tf.keras.layers.Dense(256, activation='tanh'),
                            tf.keras.layers.Dense(1,activation='sigmoid')])
model1.compile(optimizer=tf.keras.optimizers.SGD(),
               loss=tf.keras.losses.BinaryCrossentropy(),
               metrics=["accuracy","AUC"])
history1 = model1.fit(x_train, y_train, epochs=30, validation_data=(x_vali, y_vali))
# Out:
# Epoch 1/30
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.6626 - accuracy: 0.5962 - auc: 0.6322 - val_loss: 0.6499 - val_accuracy: 0.6192 - val_auc: 0.6596
# Epoch 2/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6477 - accuracy: 0.6200 - auc: 0.6618 - val_loss: 0.6472 - val_accuracy: 0.6154 - val_auc: 0.6705
# Epoch 3/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6430 - accuracy: 0.6270 - auc: 0.6705 - val_loss: 0.6408 - val_accuracy: 0.6315 - val_auc: 0.6762
# Epoch 4/30
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6399 - accuracy: 0.6309 - auc: 0.6761 - val_loss: 0.6433 - val_accuracy: 0.6199 - val_auc: 0.6820
# Epoch 5/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6372 - accuracy: 0.6361 - auc: 0.6814 - val_loss: 0.6398 - val_accuracy: 0.6341 - val_auc: 0.6857
# Epoch 6/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6351 - accuracy: 0.6402 - auc: 0.6860 - val_loss: 0.6335 - val_accuracy: 0.6420 - val_auc: 0.6892
# Epoch 7/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6334 - accuracy: 0.6418 - auc: 0.6887 - val_loss: 0.6314 - val_accuracy: 0.6456 - val_auc: 0.6942
# Epoch 8/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6316 - accuracy: 0.6446 - auc: 0.6926 - val_loss: 0.6304 - val_accuracy: 0.6487 - val_auc: 0.6964
# Epoch 9/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6298 - accuracy: 0.6479 - auc: 0.6955 - val_loss: 0.6305 - val_accuracy: 0.6453 - val_auc: 0.6969
# Epoch 10/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6287 - accuracy: 0.6499 - auc: 0.6978 - val_loss: 0.6285 - val_accuracy: 0.6493 - val_auc: 0.6986
# Epoch 11/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6273 - accuracy: 0.6511 - auc: 0.7001 - val_loss: 0.6285 - val_accuracy: 0.6501 - val_auc: 0.7032
# Epoch 12/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6257 - accuracy: 0.6535 - auc: 0.7031 - val_loss: 0.6371 - val_accuracy: 0.6379 - val_auc: 0.7040
# Epoch 13/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6244 - accuracy: 0.6555 - auc: 0.7056 - val_loss: 0.6274 - val_accuracy: 0.6507 - val_auc: 0.7039
# Epoch 14/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6232 - accuracy: 0.6563 - auc: 0.7072 - val_loss: 0.6236 - val_accuracy: 0.6558 - val_auc: 0.7072
# Epoch 15/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6221 - accuracy: 0.6582 - auc: 0.7092 - val_loss: 0.6245 - val_accuracy: 0.6543 - val_auc: 0.7101
# Epoch 16/30
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6208 - accuracy: 0.6590 - auc: 0.7113 - val_loss: 0.6206 - val_accuracy: 0.6607 - val_auc: 0.7122
# Epoch 17/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6197 - accuracy: 0.6600 - auc: 0.7131 - val_loss: 0.6227 - val_accuracy: 0.6576 - val_auc: 0.7120
# Epoch 18/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6187 - accuracy: 0.6615 - auc: 0.7146 - val_loss: 0.6194 - val_accuracy: 0.6593 - val_auc: 0.7154
# Epoch 19/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6174 - accuracy: 0.6646 - auc: 0.7167 - val_loss: 0.6179 - val_accuracy: 0.6621 - val_auc: 0.7159
# Epoch 20/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6162 - accuracy: 0.6647 - auc: 0.7184 - val_loss: 0.6173 - val_accuracy: 0.6627 - val_auc: 0.7166
# Epoch 21/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6153 - accuracy: 0.6652 - auc: 0.7198 - val_loss: 0.6168 - val_accuracy: 0.6613 - val_auc: 0.7193
# Epoch 22/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6142 - accuracy: 0.6674 - auc: 0.7214 - val_loss: 0.6162 - val_accuracy: 0.6610 - val_auc: 0.7215
# Epoch 23/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6130 - accuracy: 0.6668 - auc: 0.7231 - val_loss: 0.6135 - val_accuracy: 0.6659 - val_auc: 0.7227
# Epoch 24/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6119 - accuracy: 0.6694 - auc: 0.7248 - val_loss: 0.6151 - val_accuracy: 0.6688 - val_auc: 0.7226
# Epoch 25/30
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6107 - accuracy: 0.6692 - auc: 0.7262 - val_loss: 0.6122 - val_accuracy: 0.6673 - val_auc: 0.7245
# Epoch 26/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6093 - accuracy: 0.6706 - auc: 0.7284 - val_loss: 0.6110 - val_accuracy: 0.6679 - val_auc: 0.7261
# Epoch 27/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6085 - accuracy: 0.6713 - auc: 0.7294 - val_loss: 0.6097 - val_accuracy: 0.6706 - val_auc: 0.7277
# Epoch 28/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6071 - accuracy: 0.6727 - auc: 0.7312 - val_loss: 0.6081 - val_accuracy: 0.6728 - val_auc: 0.7303
# Epoch 29/30
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6060 - accuracy: 0.6728 - auc: 0.7329 - val_loss: 0.6081 - val_accuracy: 0.6715 - val_auc: 0.7299
# Epoch 30/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6045 - accuracy: 0.6752 - auc: 0.7346 - val_loss: 0.6090 - val_accuracy: 0.6709 - val_auc: 0.7315

# %% [markdown]
# As I am writing this notebook I just got vaccinated. My brain and my fingers are now a bit slow and inaccurate. Still I got the accuracy on the training set at around 71%, and test set around 70%.
#
# What's more interesting, however, is the AUC, or Area Under Curve. The "Curve" we are talking about is the Receiver Operating Characteristic Curve. I don't want to spend some time to explain this, since it is 1 AM now, but essentially ROC curve is the curve that shows how much true positive (_signal entries determined by the discriminator as signal_) is going to be if we adjust the discriminator cut to have certain levels of false positive (_background entries determined by the discriminator as signal_). If AUC approaches to 1, it means our discriminator (or in this case the neural network) is perfect and can allow very small false positives. If AUC is 0.5, our discriminator is no better than random guessing.
#
# The point is AUC can be used as a metric, or a number to check how well the network performs. We can use accuracy here, but if our network can provide predictions as a number between 0 and 1, the accuracy will change if we change the cut. AUC, on the other hand, can be invariant of the discriminator cut.

# %% [markdown]
# The code below will draw the evolution of loss and AUC during the training of several epochs, depending on how long you have specified your training. If the training is good, the metrics between training and validation datasets should be close. If the validation metrics are worse than training metrics, this means we have overtraining issues, and that is BAD.

# %%
# We are using the history object, which is the output of fit() method.
# If the code below screams that you do not have "history" or "auc" in history,
# you might want to check my comment.
print("SCG (learning rate=0.01)")
plt.figure(figsize=(20, 8), facecolor="white")
ax1=plt.subplot(1, 2, 1)
plt.plot(history1.history["loss"], label="training loss")
plt.plot(history1.history["val_loss"], label="validation loss")
plt.legend()
ax1.set_ylim([0.4,0.7])
plt.title("Training and testing loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
ax2=plt.subplot(1, 2, 2)
plt.plot(history1.history["auc"], label="training AUC")
plt.plot(history1.history["val_auc"], label="validation AUC")
plt.legend()
ax2.set_ylim([0.5,0.8])
plt.title("Training and testing AUC")
plt.xlabel("Epochs")
plt.ylabel("AUC")
# Out:
# SCG (learning rate=0.01)
# Text(0, 0.5, 'AUC')

# %% [markdown]
# **2) SCG with learning  rate 0.05**

# %%
model2=tf.keras.Sequential([keras.Input(shape=28),tf.keras.layers.Dense(256, activation='tanh'),tf.keras.layers.Dense(1,activation='sigmoid')])
model2.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.05),loss=tf.keras.losses.BinaryCrossentropy(),metrics=["accuracy","AUC"])
history2 = model2.fit(x_train, y_train, epochs=30, validation_data=(x_vali, y_vali))
# Out:
# Epoch 1/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6563 - accuracy: 0.6058 - auc: 0.6442 - val_loss: 0.6441 - val_accuracy: 0.6251 - val_auc: 0.6694
# Epoch 2/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6436 - accuracy: 0.6267 - auc: 0.6697 - val_loss: 0.6377 - val_accuracy: 0.6380 - val_auc: 0.6860
# Epoch 3/30
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6368 - accuracy: 0.6350 - auc: 0.6826 - val_loss: 0.6372 - val_accuracy: 0.6376 - val_auc: 0.6961
# Epoch 4/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6312 - accuracy: 0.6462 - auc: 0.6930 - val_loss: 0.6419 - val_accuracy: 0.6300 - val_auc: 0.7025
# Epoch 5/30
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6249 - accuracy: 0.6532 - auc: 0.7041 - val_loss: 0.6184 - val_accuracy: 0.6585 - val_auc: 0.7151
# Epoch 6/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6166 - accuracy: 0.6603 - auc: 0.7169 - val_loss: 0.6137 - val_accuracy: 0.6587 - val_auc: 0.7268
# Epoch 7/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6113 - accuracy: 0.6660 - auc: 0.7248 - val_loss: 0.6069 - val_accuracy: 0.6706 - val_auc: 0.7310
# Epoch 8/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6071 - accuracy: 0.6699 - auc: 0.7302 - val_loss: 0.6193 - val_accuracy: 0.6546 - val_auc: 0.7288
# Epoch 9/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6040 - accuracy: 0.6717 - auc: 0.7338 - val_loss: 0.6024 - val_accuracy: 0.6768 - val_auc: 0.7383
# Epoch 10/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6008 - accuracy: 0.6756 - auc: 0.7376 - val_loss: 0.6010 - val_accuracy: 0.6733 - val_auc: 0.7409
# Epoch 11/30
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.5983 - accuracy: 0.6786 - auc: 0.7407 - val_loss: 0.5997 - val_accuracy: 0.6777 - val_auc: 0.7389
# Epoch 12/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5957 - accuracy: 0.6817 - auc: 0.7441 - val_loss: 0.5938 - val_accuracy: 0.6816 - val_auc: 0.7470
# Epoch 13/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5944 - accuracy: 0.6816 - auc: 0.7454 - val_loss: 0.5968 - val_accuracy: 0.6781 - val_auc: 0.7477
# Epoch 14/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5928 - accuracy: 0.6826 - auc: 0.7472 - val_loss: 0.5896 - val_accuracy: 0.6871 - val_auc: 0.7521
# Epoch 15/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.5907 - accuracy: 0.6860 - auc: 0.7495 - val_loss: 0.5918 - val_accuracy: 0.6858 - val_auc: 0.7516
# Epoch 16/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5892 - accuracy: 0.6864 - auc: 0.7512 - val_loss: 0.5986 - val_accuracy: 0.6746 - val_auc: 0.7521
# Epoch 17/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5876 - accuracy: 0.6875 - auc: 0.7532 - val_loss: 0.5924 - val_accuracy: 0.6801 - val_auc: 0.7526
# Epoch 18/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5865 - accuracy: 0.6886 - auc: 0.7541 - val_loss: 0.5911 - val_accuracy: 0.6876 - val_auc: 0.7538
# Epoch 19/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5849 - accuracy: 0.6901 - auc: 0.7562 - val_loss: 0.5858 - val_accuracy: 0.6912 - val_auc: 0.7570
# Epoch 20/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5842 - accuracy: 0.6914 - auc: 0.7569 - val_loss: 0.5892 - val_accuracy: 0.6905 - val_auc: 0.7558
# Epoch 21/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.5827 - accuracy: 0.6905 - auc: 0.7584 - val_loss: 0.5882 - val_accuracy: 0.6883 - val_auc: 0.7533
# Epoch 22/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.5817 - accuracy: 0.6940 - auc: 0.7594 - val_loss: 0.5820 - val_accuracy: 0.6941 - val_auc: 0.7599
# Epoch 23/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5803 - accuracy: 0.6944 - auc: 0.7611 - val_loss: 0.5841 - val_accuracy: 0.6911 - val_auc: 0.7574
# Epoch 24/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5793 - accuracy: 0.6938 - auc: 0.7622 - val_loss: 0.5854 - val_accuracy: 0.6904 - val_auc: 0.7617
# Epoch 25/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5784 - accuracy: 0.6962 - auc: 0.7634 - val_loss: 0.5840 - val_accuracy: 0.6912 - val_auc: 0.7630
# Epoch 26/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5773 - accuracy: 0.6966 - auc: 0.7642 - val_loss: 0.5799 - val_accuracy: 0.6975 - val_auc: 0.7646
# Epoch 27/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5763 - accuracy: 0.6965 - auc: 0.7654 - val_loss: 0.5807 - val_accuracy: 0.6973 - val_auc: 0.7654
# Epoch 28/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.5755 - accuracy: 0.6989 - auc: 0.7662 - val_loss: 0.5783 - val_accuracy: 0.6964 - val_auc: 0.7637
# Epoch 29/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5749 - accuracy: 0.6970 - auc: 0.7666 - val_loss: 0.5761 - val_accuracy: 0.6977 - val_auc: 0.7658
# Epoch 30/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.5739 - accuracy: 0.6981 - auc: 0.7677 - val_loss: 0.5768 - val_accuracy: 0.6951 - val_auc: 0.7663

# %%
print("SCG (learning rate=0.05)")
plt.figure(figsize=(20, 8), facecolor="white")
ax1=plt.subplot(1, 2, 1)
plt.plot(history2.history["loss"], label="training loss")
plt.plot(history2.history["val_loss"], label="validation loss")
plt.legend()
ax1.set_ylim([0.4,0.7])
plt.title("Training and testing loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
ax2=plt.subplot(1, 2, 2)
plt.plot(history2.history["auc"], label="training AUC")
plt.plot(history2.history["val_auc"], label="validation AUC")
plt.legend()
ax2.set_ylim([0.5,0.8])
plt.title("Training and testing AUC")
plt.xlabel("Epochs")
plt.ylabel("AUC")
# Out:
# SCG (learning rate=0.05)
# Text(0, 0.5, 'AUC')

# %% [markdown]
# **3) SCG with learning rate =0.001**

# %%
model3=tf.keras.Sequential([keras.Input(shape=28),tf.keras.layers.Dense(256, activation='tanh'),tf.keras.layers.Dense(1,activation='sigmoid')])
model3.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),loss=tf.keras.losses.BinaryCrossentropy(),metrics=["accuracy","AUC"])
history3 = model3.fit(x_train, y_train, epochs=30, validation_data=(x_vali, y_vali))
# Out:
# Epoch 1/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6866 - accuracy: 0.5550 - auc: 0.5635 - val_loss: 0.6736 - val_accuracy: 0.5936 - val_auc: 0.6293
# Epoch 2/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6690 - accuracy: 0.6029 - auc: 0.6390 - val_loss: 0.6640 - val_accuracy: 0.6123 - val_auc: 0.6496
# Epoch 3/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6619 - accuracy: 0.6100 - auc: 0.6489 - val_loss: 0.6585 - val_accuracy: 0.6152 - val_auc: 0.6543
# Epoch 4/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6575 - accuracy: 0.6133 - auc: 0.6529 - val_loss: 0.6550 - val_accuracy: 0.6167 - val_auc: 0.6583
# Epoch 5/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6545 - accuracy: 0.6153 - auc: 0.6558 - val_loss: 0.6522 - val_accuracy: 0.6186 - val_auc: 0.6604
# Epoch 6/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6522 - accuracy: 0.6169 - auc: 0.6582 - val_loss: 0.6505 - val_accuracy: 0.6201 - val_auc: 0.6613
# Epoch 7/30
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6507 - accuracy: 0.6186 - auc: 0.6595 - val_loss: 0.6491 - val_accuracy: 0.6214 - val_auc: 0.6626
# Epoch 8/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6494 - accuracy: 0.6193 - auc: 0.6608 - val_loss: 0.6480 - val_accuracy: 0.6220 - val_auc: 0.6637
# Epoch 9/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6484 - accuracy: 0.6204 - auc: 0.6618 - val_loss: 0.6472 - val_accuracy: 0.6230 - val_auc: 0.6647
# Epoch 10/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6476 - accuracy: 0.6211 - auc: 0.6628 - val_loss: 0.6462 - val_accuracy: 0.6247 - val_auc: 0.6660
# Epoch 11/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6469 - accuracy: 0.6217 - auc: 0.6639 - val_loss: 0.6457 - val_accuracy: 0.6246 - val_auc: 0.6667
# Epoch 12/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6462 - accuracy: 0.6228 - auc: 0.6649 - val_loss: 0.6450 - val_accuracy: 0.6261 - val_auc: 0.6677
# Epoch 13/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6456 - accuracy: 0.6234 - auc: 0.6658 - val_loss: 0.6445 - val_accuracy: 0.6260 - val_auc: 0.6686
# Epoch 14/30
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6451 - accuracy: 0.6238 - auc: 0.6666 - val_loss: 0.6439 - val_accuracy: 0.6278 - val_auc: 0.6694
# Epoch 15/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6446 - accuracy: 0.6247 - auc: 0.6676 - val_loss: 0.6436 - val_accuracy: 0.6276 - val_auc: 0.6701
# Epoch 16/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6441 - accuracy: 0.6256 - auc: 0.6684 - val_loss: 0.6431 - val_accuracy: 0.6286 - val_auc: 0.6708
# Epoch 17/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6436 - accuracy: 0.6264 - auc: 0.6692 - val_loss: 0.6426 - val_accuracy: 0.6297 - val_auc: 0.6718
# Epoch 18/30
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6432 - accuracy: 0.6273 - auc: 0.6700 - val_loss: 0.6422 - val_accuracy: 0.6306 - val_auc: 0.6726
# Epoch 19/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6427 - accuracy: 0.6283 - auc: 0.6708 - val_loss: 0.6418 - val_accuracy: 0.6294 - val_auc: 0.6732
# Epoch 20/30
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6423 - accuracy: 0.6284 - auc: 0.6714 - val_loss: 0.6414 - val_accuracy: 0.6316 - val_auc: 0.6741
# Epoch 21/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6419 - accuracy: 0.6291 - auc: 0.6724 - val_loss: 0.6410 - val_accuracy: 0.6315 - val_auc: 0.6747
# Epoch 22/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6415 - accuracy: 0.6295 - auc: 0.6729 - val_loss: 0.6407 - val_accuracy: 0.6322 - val_auc: 0.6752
# Epoch 23/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6411 - accuracy: 0.6304 - auc: 0.6737 - val_loss: 0.6405 - val_accuracy: 0.6327 - val_auc: 0.6760
# Epoch 24/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6408 - accuracy: 0.6302 - auc: 0.6743 - val_loss: 0.6402 - val_accuracy: 0.6335 - val_auc: 0.6766
# Epoch 25/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6405 - accuracy: 0.6314 - auc: 0.6751 - val_loss: 0.6397 - val_accuracy: 0.6333 - val_auc: 0.6771
# Epoch 26/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6401 - accuracy: 0.6325 - auc: 0.6758 - val_loss: 0.6394 - val_accuracy: 0.6338 - val_auc: 0.6777
# Epoch 27/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6397 - accuracy: 0.6321 - auc: 0.6765 - val_loss: 0.6391 - val_accuracy: 0.6342 - val_auc: 0.6784
# Epoch 28/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6394 - accuracy: 0.6327 - auc: 0.6772 - val_loss: 0.6392 - val_accuracy: 0.6346 - val_auc: 0.6790
# Epoch 29/30
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6392 - accuracy: 0.6327 - auc: 0.6775 - val_loss: 0.6384 - val_accuracy: 0.6351 - val_auc: 0.6796
# Epoch 30/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6388 - accuracy: 0.6339 - auc: 0.6784 - val_loss: 0.6384 - val_accuracy: 0.6360 - val_auc: 0.6801

# %%
print("Adam (learning rate=0.001)")
plt.figure(figsize=(20, 8), facecolor="white")
ax1=plt.subplot(1, 2, 1)
plt.plot(history3.history["loss"], label="training loss")
plt.plot(history3.history["val_loss"], label="validation loss")
plt.legend()
ax1.set_ylim([0.4,0.7])
plt.title("Training and testing loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
ax2=plt.subplot(1, 2, 2)
plt.plot(history3.history["auc"], label="training AUC")
plt.plot(history3.history["val_auc"], label="validation AUC")
plt.legend()
ax2.set_ylim([0.5,0.8])
plt.title("Training and testing AUC")
plt.xlabel("Epochs")
plt.ylabel("AUC")
# Out:
# Adam (learning rate=0.001)
# Text(0, 0.5, 'AUC')

# %% [markdown]
# **4) Adam optimizer with the same learning rate**

# %%
model4=tf.keras.Sequential([keras.Input(shape=28),tf.keras.layers.Dense(256, activation='tanh'),tf.keras.layers.Dense(1,activation='sigmoid')])
model4.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),loss=tf.keras.losses.BinaryCrossentropy(),metrics=["accuracy","AUC"])
history4 = model4.fit(x_train, y_train, epochs=30, validation_data=(x_vali, y_vali))
# Out:
# Epoch 1/30
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.6664 - accuracy: 0.6048 - auc: 0.6440 - val_loss: 0.6416 - val_accuracy: 0.6322 - val_auc: 0.6870
# Epoch 2/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6427 - accuracy: 0.6409 - auc: 0.6923 - val_loss: 0.6567 - val_accuracy: 0.6439 - val_auc: 0.6956
# Epoch 3/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6403 - accuracy: 0.6468 - auc: 0.7011 - val_loss: 0.6980 - val_accuracy: 0.6129 - val_auc: 0.7197
# Epoch 4/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6361 - accuracy: 0.6530 - auc: 0.7077 - val_loss: 0.6148 - val_accuracy: 0.6656 - val_auc: 0.7249
# Epoch 5/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6334 - accuracy: 0.6560 - auc: 0.7116 - val_loss: 0.6267 - val_accuracy: 0.6604 - val_auc: 0.7287
# Epoch 6/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6359 - accuracy: 0.6545 - auc: 0.7108 - val_loss: 0.6448 - val_accuracy: 0.6497 - val_auc: 0.7101
# Epoch 7/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6345 - accuracy: 0.6565 - auc: 0.7126 - val_loss: 0.6209 - val_accuracy: 0.6649 - val_auc: 0.7281
# Epoch 8/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6366 - accuracy: 0.6556 - auc: 0.7126 - val_loss: 0.7005 - val_accuracy: 0.6232 - val_auc: 0.7344
# Epoch 9/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6317 - accuracy: 0.6601 - auc: 0.7170 - val_loss: 0.6332 - val_accuracy: 0.6657 - val_auc: 0.7307
# Epoch 10/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6318 - accuracy: 0.6606 - auc: 0.7172 - val_loss: 0.6500 - val_accuracy: 0.6505 - val_auc: 0.7339
# Epoch 11/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6254 - accuracy: 0.6650 - auc: 0.7226 - val_loss: 0.6011 - val_accuracy: 0.6776 - val_auc: 0.7420
# Epoch 12/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6283 - accuracy: 0.6618 - auc: 0.7205 - val_loss: 0.6088 - val_accuracy: 0.6744 - val_auc: 0.7370
# Epoch 13/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6278 - accuracy: 0.6643 - auc: 0.7231 - val_loss: 0.6661 - val_accuracy: 0.6422 - val_auc: 0.7320
# Epoch 14/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6265 - accuracy: 0.6660 - auc: 0.7236 - val_loss: 0.7146 - val_accuracy: 0.6203 - val_auc: 0.7151
# Epoch 15/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6265 - accuracy: 0.6641 - auc: 0.7235 - val_loss: 0.6367 - val_accuracy: 0.6600 - val_auc: 0.7302
# Epoch 16/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6236 - accuracy: 0.6668 - auc: 0.7266 - val_loss: 0.6216 - val_accuracy: 0.6659 - val_auc: 0.7279
# Epoch 17/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6243 - accuracy: 0.6660 - auc: 0.7255 - val_loss: 0.6081 - val_accuracy: 0.6746 - val_auc: 0.7415
# Epoch 18/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6203 - accuracy: 0.6694 - auc: 0.7296 - val_loss: 0.6290 - val_accuracy: 0.6635 - val_auc: 0.7430
# Epoch 19/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6210 - accuracy: 0.6690 - auc: 0.7292 - val_loss: 0.6482 - val_accuracy: 0.6508 - val_auc: 0.7291
# Epoch 20/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6201 - accuracy: 0.6705 - auc: 0.7300 - val_loss: 0.6668 - val_accuracy: 0.6371 - val_auc: 0.7354
# Epoch 21/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6189 - accuracy: 0.6703 - auc: 0.7312 - val_loss: 0.6036 - val_accuracy: 0.6785 - val_auc: 0.7413
# Epoch 22/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6190 - accuracy: 0.6714 - auc: 0.7317 - val_loss: 0.6910 - val_accuracy: 0.6286 - val_auc: 0.7405
# Epoch 23/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6201 - accuracy: 0.6685 - auc: 0.7306 - val_loss: 0.6649 - val_accuracy: 0.6422 - val_auc: 0.7408
# Epoch 24/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6181 - accuracy: 0.6723 - auc: 0.7329 - val_loss: 0.6119 - val_accuracy: 0.6760 - val_auc: 0.7385
# Epoch 25/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6165 - accuracy: 0.6714 - auc: 0.7334 - val_loss: 0.6209 - val_accuracy: 0.6707 - val_auc: 0.7389
# Epoch 26/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6151 - accuracy: 0.6728 - auc: 0.7349 - val_loss: 0.6357 - val_accuracy: 0.6663 - val_auc: 0.7452
# Epoch 27/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6144 - accuracy: 0.6729 - auc: 0.7355 - val_loss: 0.6383 - val_accuracy: 0.6622 - val_auc: 0.7347
# Epoch 28/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6154 - accuracy: 0.6724 - auc: 0.7352 - val_loss: 0.5980 - val_accuracy: 0.6829 - val_auc: 0.7483
# Epoch 29/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6152 - accuracy: 0.6738 - auc: 0.7361 - val_loss: 0.6499 - val_accuracy: 0.6505 - val_auc: 0.7456
# Epoch 30/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6152 - accuracy: 0.6746 - auc: 0.7364 - val_loss: 0.7087 - val_accuracy: 0.6210 - val_auc: 0.7390

# %%
print("Adam (learning rate=0.01)")
plt.figure(figsize=(20, 8), facecolor="white")
ax1=plt.subplot(1, 2, 1)
plt.plot(history4.history["loss"], label="training loss")
plt.plot(history4.history["val_loss"], label="validation loss")
plt.legend()
ax1.set_ylim([0.4,0.7])
plt.title("Training and testing loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
ax2=plt.subplot(1, 2, 2)
plt.plot(history4.history["auc"], label="training AUC")
plt.plot(history4.history["val_auc"], label="validation AUC")
plt.legend()
ax2.set_ylim([0.5,0.8])
plt.title("Training and testing AUC")
plt.xlabel("Epochs")
plt.ylabel("AUC")
# Out:
# Adam (learning rate=0.01)
# Text(0, 0.5, 'AUC')

# %% [markdown]
# **5) Adam Optimizer with learning rate 0.001**

# %%
model5=tf.keras.Sequential([tf.keras.layers.Dense(256, activation='tanh'),tf.keras.layers.Dense(1,activation='sigmoid')])
model5.compile(optimizer=tf.keras.optimizers.Adam(),loss=tf.keras.losses.BinaryCrossentropy(),metrics=["accuracy","AUC"])
history5 = model5.fit(x_train, y_train, epochs=30, validation_data=(x_vali, y_vali))
# Out:
# Epoch 1/30
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6525 - accuracy: 0.6111 - auc: 0.6511 - val_loss: 0.6385 - val_accuracy: 0.6316 - val_auc: 0.6837
# Epoch 2/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6365 - accuracy: 0.6385 - auc: 0.6831 - val_loss: 0.6291 - val_accuracy: 0.6465 - val_auc: 0.6966
# Epoch 3/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6284 - accuracy: 0.6487 - auc: 0.6977 - val_loss: 0.6216 - val_accuracy: 0.6561 - val_auc: 0.7096
# Epoch 4/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6206 - accuracy: 0.6573 - auc: 0.7105 - val_loss: 0.6249 - val_accuracy: 0.6537 - val_auc: 0.7180
# Epoch 5/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6133 - accuracy: 0.6656 - auc: 0.7215 - val_loss: 0.6171 - val_accuracy: 0.6645 - val_auc: 0.7285
# Epoch 6/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6081 - accuracy: 0.6702 - auc: 0.7284 - val_loss: 0.6170 - val_accuracy: 0.6543 - val_auc: 0.7332
# Epoch 7/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.6033 - accuracy: 0.6750 - auc: 0.7347 - val_loss: 0.6062 - val_accuracy: 0.6721 - val_auc: 0.7340
# Epoch 8/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5993 - accuracy: 0.6782 - auc: 0.7393 - val_loss: 0.5986 - val_accuracy: 0.6786 - val_auc: 0.7413
# Epoch 9/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5960 - accuracy: 0.6799 - auc: 0.7436 - val_loss: 0.5997 - val_accuracy: 0.6807 - val_auc: 0.7448
# Epoch 10/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5933 - accuracy: 0.6833 - auc: 0.7465 - val_loss: 0.5969 - val_accuracy: 0.6833 - val_auc: 0.7456
# Epoch 11/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5911 - accuracy: 0.6853 - auc: 0.7489 - val_loss: 0.5930 - val_accuracy: 0.6816 - val_auc: 0.7481
# Epoch 12/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5882 - accuracy: 0.6866 - auc: 0.7521 - val_loss: 0.5898 - val_accuracy: 0.6871 - val_auc: 0.7507
# Epoch 13/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5862 - accuracy: 0.6904 - auc: 0.7548 - val_loss: 0.5891 - val_accuracy: 0.6885 - val_auc: 0.7527
# Epoch 14/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5839 - accuracy: 0.6902 - auc: 0.7569 - val_loss: 0.5908 - val_accuracy: 0.6856 - val_auc: 0.7510
# Epoch 15/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5824 - accuracy: 0.6911 - auc: 0.7585 - val_loss: 0.5873 - val_accuracy: 0.6880 - val_auc: 0.7547
# Epoch 16/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5802 - accuracy: 0.6934 - auc: 0.7609 - val_loss: 0.5870 - val_accuracy: 0.6850 - val_auc: 0.7583
# Epoch 17/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5790 - accuracy: 0.6933 - auc: 0.7621 - val_loss: 0.5831 - val_accuracy: 0.6924 - val_auc: 0.7587
# Epoch 18/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5773 - accuracy: 0.6953 - auc: 0.7638 - val_loss: 0.5826 - val_accuracy: 0.6918 - val_auc: 0.7603
# Epoch 19/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5756 - accuracy: 0.6962 - auc: 0.7657 - val_loss: 0.5878 - val_accuracy: 0.6898 - val_auc: 0.7587
# Epoch 20/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5746 - accuracy: 0.6972 - auc: 0.7667 - val_loss: 0.5799 - val_accuracy: 0.6947 - val_auc: 0.7621
# Epoch 21/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5733 - accuracy: 0.6991 - auc: 0.7681 - val_loss: 0.5823 - val_accuracy: 0.6943 - val_auc: 0.7619
# Epoch 22/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5721 - accuracy: 0.6998 - auc: 0.7695 - val_loss: 0.5790 - val_accuracy: 0.6971 - val_auc: 0.7647
# Epoch 23/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5705 - accuracy: 0.7010 - auc: 0.7709 - val_loss: 0.5906 - val_accuracy: 0.6823 - val_auc: 0.7626
# Epoch 24/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5698 - accuracy: 0.7024 - auc: 0.7718 - val_loss: 0.5827 - val_accuracy: 0.6898 - val_auc: 0.7636
# Epoch 25/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5684 - accuracy: 0.7030 - auc: 0.7731 - val_loss: 0.5839 - val_accuracy: 0.6943 - val_auc: 0.7641
# Epoch 26/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5675 - accuracy: 0.7035 - auc: 0.7740 - val_loss: 0.5808 - val_accuracy: 0.6943 - val_auc: 0.7618
# Epoch 27/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5659 - accuracy: 0.7050 - auc: 0.7759 - val_loss: 0.5795 - val_accuracy: 0.6955 - val_auc: 0.7654
# Epoch 28/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5653 - accuracy: 0.7059 - auc: 0.7763 - val_loss: 0.5807 - val_accuracy: 0.6959 - val_auc: 0.7657
# Epoch 29/30
# 3125/3125 [==============================] - 8s 3ms/step - loss: 0.5647 - accuracy: 0.7060 - auc: 0.7768 - val_loss: 0.5765 - val_accuracy: 0.6975 - val_auc: 0.7668
# Epoch 30/30
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5633 - accuracy: 0.7062 - auc: 0.7783 - val_loss: 0.5760 - val_accuracy: 0.6987 - val_auc: 0.7665

# %%
print("Adam (learning rate=0.001)")
plt.figure(figsize=(20, 8), facecolor="white")
ax1=plt.subplot(1, 2, 1)
plt.plot(history5.history["loss"], label="training loss")
plt.plot(history5.history["val_loss"], label="validation loss")
plt.legend()
ax1.set_ylim([0.4,0.7])
plt.title("Training and testing loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
ax2=plt.subplot(1, 2, 2)
plt.plot(history5.history["auc"], label="training AUC")
plt.plot(history5.history["val_auc"], label="validation AUC")
plt.legend()
ax2.set_ylim([0.5,0.8])
plt.title("Training and testing AUC")
plt.xlabel("Epochs")
plt.ylabel("AUC")
# Out:
# Adam (learning rate=0.001)
# Text(0, 0.5, 'AUC')

# %% [markdown]
# ---
#
#
#
# Then, we choose whether SGD with learning rate 0.05 or Adam with learning rate 0.001.
#
# In this example, I'll use SGD with learning rate 0.05 and epoch 20. After that changing on number of layer/activation function
#
# number of of layer is  128 256 512
# Activation fucntion in hidden layers is "Relu" "tanh" "sigmoid"

# %% [markdown]
# **Activation=tanh , number of neuron = 256**

# %%
modeltanh=tf.keras.Sequential([keras.Input(shape=28),tf.keras.layers.Dense(256, activation='tanh'),tf.keras.layers.Dense(1,activation='sigmoid')])
modeltanh.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.05),loss=tf.keras.losses.BinaryCrossentropy(),metrics=["accuracy","AUC"])
historytanh = modeltanh.fit(x_train, y_train, epochs=20, validation_data=(x_vali, y_vali))
# Out:
# Epoch 1/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6567 - accuracy: 0.6040 - auc: 0.6432 - val_loss: 0.6410 - val_accuracy: 0.6306 - val_auc: 0.6745
# Epoch 2/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6433 - accuracy: 0.6263 - auc: 0.6706 - val_loss: 0.6358 - val_accuracy: 0.6384 - val_auc: 0.6850
# Epoch 3/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6355 - accuracy: 0.6396 - auc: 0.6857 - val_loss: 0.6315 - val_accuracy: 0.6428 - val_auc: 0.7023
# Epoch 4/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6287 - accuracy: 0.6482 - auc: 0.6979 - val_loss: 0.6232 - val_accuracy: 0.6525 - val_auc: 0.7117
# Epoch 5/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6218 - accuracy: 0.6563 - auc: 0.7098 - val_loss: 0.6234 - val_accuracy: 0.6522 - val_auc: 0.7130
# Epoch 6/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6143 - accuracy: 0.6636 - auc: 0.7205 - val_loss: 0.6112 - val_accuracy: 0.6683 - val_auc: 0.7276
# Epoch 7/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6102 - accuracy: 0.6665 - auc: 0.7264 - val_loss: 0.6046 - val_accuracy: 0.6745 - val_auc: 0.7352
# Epoch 8/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6063 - accuracy: 0.6715 - auc: 0.7318 - val_loss: 0.6026 - val_accuracy: 0.6747 - val_auc: 0.7374
# Epoch 9/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6038 - accuracy: 0.6723 - auc: 0.7346 - val_loss: 0.6033 - val_accuracy: 0.6754 - val_auc: 0.7356
# Epoch 10/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6010 - accuracy: 0.6764 - auc: 0.7379 - val_loss: 0.6041 - val_accuracy: 0.6709 - val_auc: 0.7374
# Epoch 11/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5994 - accuracy: 0.6790 - auc: 0.7399 - val_loss: 0.5982 - val_accuracy: 0.6786 - val_auc: 0.7418
# Epoch 12/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.5971 - accuracy: 0.6788 - auc: 0.7424 - val_loss: 0.6036 - val_accuracy: 0.6710 - val_auc: 0.7429
# Epoch 13/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5959 - accuracy: 0.6801 - auc: 0.7437 - val_loss: 0.5992 - val_accuracy: 0.6809 - val_auc: 0.7456
# Epoch 14/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5936 - accuracy: 0.6830 - auc: 0.7466 - val_loss: 0.5938 - val_accuracy: 0.6831 - val_auc: 0.7469
# Epoch 15/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5922 - accuracy: 0.6831 - auc: 0.7477 - val_loss: 0.5916 - val_accuracy: 0.6880 - val_auc: 0.7507
# Epoch 16/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.5911 - accuracy: 0.6845 - auc: 0.7492 - val_loss: 0.5990 - val_accuracy: 0.6828 - val_auc: 0.7539
# Epoch 17/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5895 - accuracy: 0.6866 - auc: 0.7510 - val_loss: 0.5889 - val_accuracy: 0.6889 - val_auc: 0.7540
# Epoch 18/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5881 - accuracy: 0.6869 - auc: 0.7527 - val_loss: 0.5904 - val_accuracy: 0.6836 - val_auc: 0.7523
# Epoch 19/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5873 - accuracy: 0.6876 - auc: 0.7534 - val_loss: 0.5964 - val_accuracy: 0.6771 - val_auc: 0.7546
# Epoch 20/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5859 - accuracy: 0.6886 - auc: 0.7548 - val_loss: 0.5896 - val_accuracy: 0.6906 - val_auc: 0.7565

# %%
print("SCG (learning rate=0.05)")
plt.figure(figsize=(20, 8), facecolor="white")
ax1=plt.subplot(1, 2, 1)
plt.plot(historytanh.history["loss"], label="training loss")
plt.plot(historytanh.history["val_loss"], label="validation loss")
plt.legend()
ax1.set_ylim([0.4,0.7])
plt.title("Training and testing loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
ax2=plt.subplot(1, 2, 2)
plt.plot(historytanh.history["auc"], label="training AUC")
plt.plot(historytanh.history["val_auc"], label="validation AUC")
plt.legend()
ax2.set_ylim([0.5,0.8])
plt.title("Training and testing AUC")
plt.xlabel("Epochs")
plt.ylabel("AUC")
# Out:
# SCG (learning rate=0.05)
# Text(0, 0.5, 'AUC')

# %% [markdown]
# **Activation=sigmoid , number of neuron = 256**

# %%
modelsig=tf.keras.Sequential([keras.Input(shape=28),tf.keras.layers.Dense(256, activation='sigmoid'),tf.keras.layers.Dense(1,activation='sigmoid')])
modelsig.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.05),loss=tf.keras.losses.BinaryCrossentropy(),metrics=["accuracy","AUC"])
historysig = modelsig.fit(x_train, y_train, epochs=20, validation_data=(x_vali, y_vali))
# Out:
# Epoch 1/20
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.6751 - accuracy: 0.5719 - auc: 0.5985 - val_loss: 0.6512 - val_accuracy: 0.6176 - val_auc: 0.6561
# Epoch 2/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6596 - accuracy: 0.5996 - auc: 0.6377 - val_loss: 0.6484 - val_accuracy: 0.6220 - val_auc: 0.6642
# Epoch 3/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6547 - accuracy: 0.6095 - auc: 0.6482 - val_loss: 0.6445 - val_accuracy: 0.6269 - val_auc: 0.6700
# Epoch 4/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6511 - accuracy: 0.6142 - auc: 0.6548 - val_loss: 0.6430 - val_accuracy: 0.6289 - val_auc: 0.6732
# Epoch 5/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6478 - accuracy: 0.6198 - auc: 0.6614 - val_loss: 0.6449 - val_accuracy: 0.6275 - val_auc: 0.6760
# Epoch 6/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6462 - accuracy: 0.6219 - auc: 0.6647 - val_loss: 0.6443 - val_accuracy: 0.6217 - val_auc: 0.6782
# Epoch 7/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6439 - accuracy: 0.6263 - auc: 0.6698 - val_loss: 0.6367 - val_accuracy: 0.6387 - val_auc: 0.6831
# Epoch 8/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6419 - accuracy: 0.6292 - auc: 0.6734 - val_loss: 0.6452 - val_accuracy: 0.6297 - val_auc: 0.6863
# Epoch 9/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6390 - accuracy: 0.6336 - auc: 0.6786 - val_loss: 0.6331 - val_accuracy: 0.6432 - val_auc: 0.6908
# Epoch 10/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6374 - accuracy: 0.6369 - auc: 0.6824 - val_loss: 0.6325 - val_accuracy: 0.6438 - val_auc: 0.6942
# Epoch 11/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6349 - accuracy: 0.6404 - auc: 0.6868 - val_loss: 0.6334 - val_accuracy: 0.6445 - val_auc: 0.6954
# Epoch 12/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6329 - accuracy: 0.6429 - auc: 0.6905 - val_loss: 0.6534 - val_accuracy: 0.6064 - val_auc: 0.6993
# Epoch 13/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6305 - accuracy: 0.6458 - auc: 0.6948 - val_loss: 0.6267 - val_accuracy: 0.6543 - val_auc: 0.7022
# Epoch 14/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6288 - accuracy: 0.6492 - auc: 0.6979 - val_loss: 0.6280 - val_accuracy: 0.6489 - val_auc: 0.7053
# Epoch 15/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6268 - accuracy: 0.6511 - auc: 0.7015 - val_loss: 0.6232 - val_accuracy: 0.6582 - val_auc: 0.7086
# Epoch 16/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6253 - accuracy: 0.6541 - auc: 0.7041 - val_loss: 0.6212 - val_accuracy: 0.6594 - val_auc: 0.7113
# Epoch 17/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6234 - accuracy: 0.6561 - auc: 0.7073 - val_loss: 0.6258 - val_accuracy: 0.6484 - val_auc: 0.7153
# Epoch 18/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6212 - accuracy: 0.6590 - auc: 0.7112 - val_loss: 0.6178 - val_accuracy: 0.6611 - val_auc: 0.7178
# Epoch 19/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6190 - accuracy: 0.6607 - auc: 0.7146 - val_loss: 0.6169 - val_accuracy: 0.6611 - val_auc: 0.7197
# Epoch 20/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6166 - accuracy: 0.6635 - auc: 0.7183 - val_loss: 0.6146 - val_accuracy: 0.6648 - val_auc: 0.7225

# %%
print("SGD (learning rate=0.05) , activation = Sigmoid")
plt.figure(figsize=(20, 8), facecolor="white")
ax1=plt.subplot(1, 2, 1)
plt.plot(historysig.history["loss"], label="training loss")
plt.plot(historysig.history["val_loss"], label="validation loss")
plt.legend()
ax1.set_ylim([0.4,0.7])
plt.title("Training and testing loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
ax2=plt.subplot(1, 2, 2)
plt.plot(historysig.history["auc"], label="training AUC")
plt.plot(historysig.history["val_auc"], label="validation AUC")
plt.legend()
ax2.set_ylim([0.5,0.8])
plt.title("Training and testing AUC")
plt.xlabel("Epochs")
plt.ylabel("AUC")
# Out:
# SGD (learning rate=0.05) , activation = Sigmoid
# Text(0, 0.5, 'AUC')

# %% [markdown]
# **Activation=Relu , number of neuron = 256**

# %%
modelRelu=tf.keras.Sequential([keras.Input(shape=28),tf.keras.layers.Dense(256, activation='relu'),tf.keras.layers.Dense(1,activation='sigmoid')])
modelRelu.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.05),loss=tf.keras.losses.BinaryCrossentropy(),metrics=["accuracy","AUC"])
historyRelu = modelRelu.fit(x_train, y_train, epochs=20, validation_data=(x_vali, y_vali))
# Out:
# Epoch 1/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6504 - accuracy: 0.6127 - auc: 0.6554 - val_loss: 0.6385 - val_accuracy: 0.6324 - val_auc: 0.6830
# Epoch 2/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6304 - accuracy: 0.6435 - auc: 0.6927 - val_loss: 0.6224 - val_accuracy: 0.6530 - val_auc: 0.7073
# Epoch 3/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6181 - accuracy: 0.6572 - auc: 0.7137 - val_loss: 0.6111 - val_accuracy: 0.6661 - val_auc: 0.7262
# Epoch 4/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6079 - accuracy: 0.6684 - auc: 0.7303 - val_loss: 0.6063 - val_accuracy: 0.6655 - val_auc: 0.7348
# Epoch 5/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6032 - accuracy: 0.6725 - auc: 0.7362 - val_loss: 0.6062 - val_accuracy: 0.6636 - val_auc: 0.7408
# Epoch 6/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5997 - accuracy: 0.6765 - auc: 0.7409 - val_loss: 0.6106 - val_accuracy: 0.6711 - val_auc: 0.7369
# Epoch 7/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5961 - accuracy: 0.6815 - auc: 0.7454 - val_loss: 0.6051 - val_accuracy: 0.6781 - val_auc: 0.7432
# Epoch 8/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5936 - accuracy: 0.6817 - auc: 0.7483 - val_loss: 0.5965 - val_accuracy: 0.6805 - val_auc: 0.7434
# Epoch 9/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5907 - accuracy: 0.6841 - auc: 0.7510 - val_loss: 0.5974 - val_accuracy: 0.6737 - val_auc: 0.7455
# Epoch 10/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.5886 - accuracy: 0.6868 - auc: 0.7531 - val_loss: 0.5934 - val_accuracy: 0.6813 - val_auc: 0.7473
# Epoch 11/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5860 - accuracy: 0.6887 - auc: 0.7562 - val_loss: 0.5925 - val_accuracy: 0.6843 - val_auc: 0.7496
# Epoch 12/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.5838 - accuracy: 0.6907 - auc: 0.7583 - val_loss: 0.5892 - val_accuracy: 0.6832 - val_auc: 0.7525
# Epoch 13/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5819 - accuracy: 0.6910 - auc: 0.7602 - val_loss: 0.5883 - val_accuracy: 0.6844 - val_auc: 0.7562
# Epoch 14/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5794 - accuracy: 0.6941 - auc: 0.7626 - val_loss: 0.5879 - val_accuracy: 0.6919 - val_auc: 0.7565
# Epoch 15/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5776 - accuracy: 0.6943 - auc: 0.7648 - val_loss: 0.5909 - val_accuracy: 0.6825 - val_auc: 0.7535
# Epoch 16/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.5756 - accuracy: 0.6967 - auc: 0.7665 - val_loss: 0.5879 - val_accuracy: 0.6858 - val_auc: 0.7552
# Epoch 17/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5739 - accuracy: 0.6991 - auc: 0.7689 - val_loss: 0.5832 - val_accuracy: 0.6903 - val_auc: 0.7593
# Epoch 18/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5723 - accuracy: 0.7000 - auc: 0.7699 - val_loss: 0.5909 - val_accuracy: 0.6839 - val_auc: 0.7561
# Epoch 19/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5700 - accuracy: 0.7020 - auc: 0.7726 - val_loss: 0.5803 - val_accuracy: 0.6950 - val_auc: 0.7621
# Epoch 20/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5682 - accuracy: 0.7024 - auc: 0.7743 - val_loss: 0.5782 - val_accuracy: 0.6963 - val_auc: 0.7642

# %%
print("SGD (learning rate=0.05) , activation = Relu")
plt.figure(figsize=(20, 8), facecolor="white")
ax1=plt.subplot(1, 2, 1)
plt.plot(historyRelu.history["loss"], label="training loss")
plt.plot(historyRelu.history["val_loss"], label="validation loss")
plt.legend()
ax1.set_ylim([0.4,0.7])
plt.title("Training and testing loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
ax2=plt.subplot(1, 2, 2)
plt.plot(historyRelu.history["auc"], label="training AUC")
plt.plot(historyRelu.history["val_auc"], label="validation AUC")
plt.legend()
ax2.set_ylim([0.5,0.8])
plt.title("Training and testing AUC")
plt.xlabel("Epochs")
plt.ylabel("AUC")
# Out:
# SGD (learning rate=0.05) , activation = Relu
# Text(0, 0.5, 'AUC')

# %% [markdown]
# **Activation=tanh , number of neuron = 128**

# %%
modeltanh128=tf.keras.Sequential([keras.Input(shape=28),tf.keras.layers.Dense(128, activation='tanh'),tf.keras.layers.Dense(1,activation='sigmoid')])
modeltanh128.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.05),loss=tf.keras.losses.BinaryCrossentropy(),metrics=["accuracy","AUC"])
historytanh128 = modeltanh128.fit(x_train, y_train, epochs=20, validation_data=(x_vali, y_vali))
# Out:
# Epoch 1/20
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.6558 - accuracy: 0.6051 - auc: 0.6444 - val_loss: 0.6434 - val_accuracy: 0.6282 - val_auc: 0.6771
# Epoch 2/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6405 - accuracy: 0.6292 - auc: 0.6752 - val_loss: 0.6377 - val_accuracy: 0.6330 - val_auc: 0.6871
# Epoch 3/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6319 - accuracy: 0.6420 - auc: 0.6909 - val_loss: 0.6252 - val_accuracy: 0.6535 - val_auc: 0.7056
# Epoch 4/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6239 - accuracy: 0.6524 - auc: 0.7041 - val_loss: 0.6222 - val_accuracy: 0.6569 - val_auc: 0.7144
# Epoch 5/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6160 - accuracy: 0.6601 - auc: 0.7166 - val_loss: 0.6090 - val_accuracy: 0.6686 - val_auc: 0.7274
# Epoch 6/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6097 - accuracy: 0.6658 - auc: 0.7254 - val_loss: 0.6068 - val_accuracy: 0.6721 - val_auc: 0.7317
# Epoch 7/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6057 - accuracy: 0.6716 - auc: 0.7313 - val_loss: 0.6064 - val_accuracy: 0.6668 - val_auc: 0.7355
# Epoch 8/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.6032 - accuracy: 0.6743 - auc: 0.7351 - val_loss: 0.6063 - val_accuracy: 0.6739 - val_auc: 0.7359
# Epoch 9/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.6004 - accuracy: 0.6769 - auc: 0.7381 - val_loss: 0.6028 - val_accuracy: 0.6760 - val_auc: 0.7380
# Epoch 10/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.5982 - accuracy: 0.6784 - auc: 0.7410 - val_loss: 0.6003 - val_accuracy: 0.6776 - val_auc: 0.7396
# Epoch 11/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.5967 - accuracy: 0.6803 - auc: 0.7424 - val_loss: 0.6105 - val_accuracy: 0.6741 - val_auc: 0.7447
# Epoch 12/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.5947 - accuracy: 0.6825 - auc: 0.7452 - val_loss: 0.5979 - val_accuracy: 0.6792 - val_auc: 0.7418
# Epoch 13/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5935 - accuracy: 0.6827 - auc: 0.7463 - val_loss: 0.6017 - val_accuracy: 0.6805 - val_auc: 0.7474
# Epoch 14/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5920 - accuracy: 0.6828 - auc: 0.7480 - val_loss: 0.5924 - val_accuracy: 0.6860 - val_auc: 0.7494
# Epoch 15/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.5898 - accuracy: 0.6844 - auc: 0.7503 - val_loss: 0.5916 - val_accuracy: 0.6828 - val_auc: 0.7521
# Epoch 16/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.5883 - accuracy: 0.6866 - auc: 0.7522 - val_loss: 0.5938 - val_accuracy: 0.6818 - val_auc: 0.7503
# Epoch 17/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.5863 - accuracy: 0.6884 - auc: 0.7545 - val_loss: 0.6014 - val_accuracy: 0.6798 - val_auc: 0.7550
# Epoch 18/20
# 3125/3125 [==============================] - 7s 2ms/step - loss: 0.5853 - accuracy: 0.6889 - auc: 0.7555 - val_loss: 0.5870 - val_accuracy: 0.6907 - val_auc: 0.7556
# Epoch 19/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.5840 - accuracy: 0.6902 - auc: 0.7570 - val_loss: 0.5881 - val_accuracy: 0.6866 - val_auc: 0.7528
# Epoch 20/20
# 3125/3125 [==============================] - 9s 3ms/step - loss: 0.5822 - accuracy: 0.6911 - auc: 0.7589 - val_loss: 0.5858 - val_accuracy: 0.6895 - val_auc: 0.7566

# %%
print("SGD (learning rate=0.05) , activation = tanh ,128")
plt.figure(figsize=(20, 8), facecolor="white")
ax1=plt.subplot(1, 2, 1)
plt.plot(historytanh128.history["loss"], label="training loss")
plt.plot(historytanh128.history["val_loss"], label="validation loss")
plt.legend()
ax1.set_ylim([0.4,0.7])
plt.title("Training and testing loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
ax2=plt.subplot(1, 2, 2)
plt.plot(historytanh128.history["auc"], label="training AUC")
plt.plot(historytanh128.history["val_auc"], label="validation AUC")
plt.legend()
ax2.set_ylim([0.5,0.8])
plt.title("Training and testing AUC")
plt.xlabel("Epochs")
plt.ylabel("AUC")
# Out:
# SGD (learning rate=0.05) , activation = tanh ,128
# Text(0, 0.5, 'AUC')

# %% [markdown]
# **Activation=tanh , number of neuron = 512**

# %%
modeltanh512=tf.keras.Sequential([keras.Input(shape=28),tf.keras.layers.Dense(512, activation='tanh'),tf.keras.layers.Dense(1,activation='sigmoid')])
modeltanh512.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.05),loss=tf.keras.losses.BinaryCrossentropy(),metrics=["accuracy","AUC"])
historytanh512 = modeltanh512.fit(x_train, y_train, epochs=20, validation_data=(x_vali, y_vali))
# Out:
# Epoch 1/20
# 3125/3125 [==============================] - 11s 3ms/step - loss: 0.6574 - accuracy: 0.6028 - auc: 0.6417 - val_loss: 0.6497 - val_accuracy: 0.6125 - val_auc: 0.6608
# Epoch 2/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6471 - accuracy: 0.6208 - auc: 0.6631 - val_loss: 0.6406 - val_accuracy: 0.6318 - val_auc: 0.6755
# Epoch 3/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6400 - accuracy: 0.6316 - auc: 0.6773 - val_loss: 0.6404 - val_accuracy: 0.6331 - val_auc: 0.6766
# Epoch 4/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6328 - accuracy: 0.6434 - auc: 0.6909 - val_loss: 0.6236 - val_accuracy: 0.6562 - val_auc: 0.7085
# Epoch 5/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6257 - accuracy: 0.6521 - auc: 0.7040 - val_loss: 0.6164 - val_accuracy: 0.6596 - val_auc: 0.7205
# Epoch 6/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6189 - accuracy: 0.6597 - auc: 0.7146 - val_loss: 0.6266 - val_accuracy: 0.6551 - val_auc: 0.7248
# Epoch 7/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6140 - accuracy: 0.6637 - auc: 0.7221 - val_loss: 0.6128 - val_accuracy: 0.6682 - val_auc: 0.7286
# Epoch 8/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6103 - accuracy: 0.6688 - auc: 0.7276 - val_loss: 0.6094 - val_accuracy: 0.6648 - val_auc: 0.7310
# Epoch 9/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6073 - accuracy: 0.6709 - auc: 0.7311 - val_loss: 0.6032 - val_accuracy: 0.6742 - val_auc: 0.7373
# Epoch 10/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6045 - accuracy: 0.6734 - auc: 0.7346 - val_loss: 0.6022 - val_accuracy: 0.6736 - val_auc: 0.7393
# Epoch 11/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.6027 - accuracy: 0.6755 - auc: 0.7370 - val_loss: 0.6018 - val_accuracy: 0.6781 - val_auc: 0.7393
# Epoch 12/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.6009 - accuracy: 0.6771 - auc: 0.7390 - val_loss: 0.6028 - val_accuracy: 0.6802 - val_auc: 0.7436
# Epoch 13/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5983 - accuracy: 0.6798 - auc: 0.7420 - val_loss: 0.6048 - val_accuracy: 0.6685 - val_auc: 0.7438
# Epoch 14/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5970 - accuracy: 0.6810 - auc: 0.7434 - val_loss: 0.5983 - val_accuracy: 0.6728 - val_auc: 0.7508
# Epoch 15/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5951 - accuracy: 0.6825 - auc: 0.7458 - val_loss: 0.5984 - val_accuracy: 0.6838 - val_auc: 0.7492
# Epoch 16/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5937 - accuracy: 0.6833 - auc: 0.7469 - val_loss: 0.5971 - val_accuracy: 0.6760 - val_auc: 0.7480
# Epoch 17/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.5921 - accuracy: 0.6848 - auc: 0.7491 - val_loss: 0.5923 - val_accuracy: 0.6878 - val_auc: 0.7527
# Epoch 18/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5908 - accuracy: 0.6856 - auc: 0.7503 - val_loss: 0.5947 - val_accuracy: 0.6873 - val_auc: 0.7533
# Epoch 19/20
# 3125/3125 [==============================] - 8s 2ms/step - loss: 0.5891 - accuracy: 0.6888 - auc: 0.7525 - val_loss: 0.5912 - val_accuracy: 0.6824 - val_auc: 0.7546
# Epoch 20/20
# 3125/3125 [==============================] - 10s 3ms/step - loss: 0.5881 - accuracy: 0.6889 - auc: 0.7534 - val_loss: 0.5862 - val_accuracy: 0.6891 - val_auc: 0.7570

# %%
print("SGD (learning rate=0.05) , activation = tanh ,512")
plt.figure(figsize=(20, 8), facecolor="white")
ax1=plt.subplot(1, 2, 1)
plt.plot(historytanh512.history["loss"], label="training loss")
plt.plot(historytanh512.history["val_loss"], label="validation loss")
plt.legend()
ax1.set_ylim([0.4,0.7])
plt.title("Training and testing loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
ax2=plt.subplot(1, 2, 2)
plt.plot(historytanh512.history["auc"], label="training AUC")
plt.plot(historytanh512.history["val_auc"], label="validation AUC")
plt.legend()
ax2.set_ylim([0.5,0.8])
plt.title("Training and testing AUC")
plt.xlabel("Epochs")
plt.ylabel("AUC")
# Out:
# SGD (learning rate=0.05) , activation = tanh ,512
# Text(0, 0.5, 'AUC')

# %% [markdown]
# So far I have only managed to get AUC of around 0.76-0.78, but I only have a few hours to work on this. Let's see if your model gets better AUC. Good luck!

# %% [markdown]
# **For evaluation**, I'll use the SGD optimizer with relu and number of neuron is 256 with 50 epoch

# %%
model=tf.keras.Sequential([keras.Input(shape=28),
                           tf.keras.layers.Dense(256, activation='relu'),
                           tf.keras.layers.Dense(1,activation='sigmoid')])
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.05),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=["accuracy","AUC"])
history = model.fit(x_train, y_train, epochs=50,verbose=2, validation_data=(x_vali, y_vali))
# Out:
# Epoch 1/50
# 3125/3125 - 9s - loss: 0.6504 - accuracy: 0.6139 - auc: 0.6558 - val_loss: 0.6415 - val_accuracy: 0.6257 - val_auc: 0.6861
# Epoch 2/50
# 3125/3125 - 6s - loss: 0.6292 - accuracy: 0.6447 - auc: 0.6950 - val_loss: 0.6217 - val_accuracy: 0.6540 - val_auc: 0.7093
# Epoch 3/50
# 3125/3125 - 8s - loss: 0.6164 - accuracy: 0.6580 - auc: 0.7165 - val_loss: 0.6130 - val_accuracy: 0.6606 - val_auc: 0.7237
# Epoch 4/50
# 3125/3125 - 6s - loss: 0.6085 - accuracy: 0.6673 - auc: 0.7281 - val_loss: 0.6098 - val_accuracy: 0.6636 - val_auc: 0.7284
# Epoch 5/50
# 3125/3125 - 6s - loss: 0.6038 - accuracy: 0.6734 - auc: 0.7350 - val_loss: 0.6028 - val_accuracy: 0.6716 - val_auc: 0.7380
# Epoch 6/50
# 3125/3125 - 8s - loss: 0.6002 - accuracy: 0.6744 - auc: 0.7394 - val_loss: 0.6036 - val_accuracy: 0.6674 - val_auc: 0.7397
# Epoch 7/50
# 3125/3125 - 6s - loss: 0.5961 - accuracy: 0.6797 - auc: 0.7444 - val_loss: 0.5961 - val_accuracy: 0.6791 - val_auc: 0.7454
# Epoch 8/50
# 3125/3125 - 6s - loss: 0.5931 - accuracy: 0.6821 - auc: 0.7483 - val_loss: 0.5977 - val_accuracy: 0.6780 - val_auc: 0.7429
# Epoch 9/50
# 3125/3125 - 8s - loss: 0.5909 - accuracy: 0.6833 - auc: 0.7503 - val_loss: 0.6016 - val_accuracy: 0.6699 - val_auc: 0.7466
# Epoch 10/50
# 3125/3125 - 8s - loss: 0.5883 - accuracy: 0.6873 - auc: 0.7531 - val_loss: 0.5920 - val_accuracy: 0.6856 - val_auc: 0.7498
# Epoch 11/50
# 3125/3125 - 8s - loss: 0.5858 - accuracy: 0.6873 - auc: 0.7555 - val_loss: 0.5900 - val_accuracy: 0.6825 - val_auc: 0.7528
# Epoch 12/50
# 3125/3125 - 6s - loss: 0.5832 - accuracy: 0.6903 - auc: 0.7586 - val_loss: 0.5966 - val_accuracy: 0.6709 - val_auc: 0.7537
# Epoch 13/50
# 3125/3125 - 6s - loss: 0.5810 - accuracy: 0.6908 - auc: 0.7605 - val_loss: 0.5886 - val_accuracy: 0.6834 - val_auc: 0.7526
# Epoch 14/50
# 3125/3125 - 8s - loss: 0.5791 - accuracy: 0.6934 - auc: 0.7624 - val_loss: 0.5894 - val_accuracy: 0.6904 - val_auc: 0.7570
# Epoch 15/50
# 3125/3125 - 8s - loss: 0.5782 - accuracy: 0.6947 - auc: 0.7637 - val_loss: 0.5915 - val_accuracy: 0.6884 - val_auc: 0.7594
# Epoch 16/50
# 3125/3125 - 8s - loss: 0.5753 - accuracy: 0.6956 - auc: 0.7668 - val_loss: 0.5847 - val_accuracy: 0.6891 - val_auc: 0.7569
# Epoch 17/50
# 3125/3125 - 6s - loss: 0.5741 - accuracy: 0.6967 - auc: 0.7678 - val_loss: 0.5833 - val_accuracy: 0.6901 - val_auc: 0.7596
# Epoch 18/50
# 3125/3125 - 8s - loss: 0.5722 - accuracy: 0.7008 - auc: 0.7702 - val_loss: 0.5828 - val_accuracy: 0.6939 - val_auc: 0.7606
# Epoch 19/50
# 3125/3125 - 6s - loss: 0.5711 - accuracy: 0.7001 - auc: 0.7711 - val_loss: 0.5826 - val_accuracy: 0.6918 - val_auc: 0.7588
# Epoch 20/50
# 3125/3125 - 6s - loss: 0.5695 - accuracy: 0.7014 - auc: 0.7726 - val_loss: 0.5804 - val_accuracy: 0.6927 - val_auc: 0.7642
# Epoch 21/50
# 3125/3125 - 8s - loss: 0.5682 - accuracy: 0.7027 - auc: 0.7742 - val_loss: 0.6275 - val_accuracy: 0.6712 - val_auc: 0.7587
# Epoch 22/50
# 3125/3125 - 8s - loss: 0.5673 - accuracy: 0.7030 - auc: 0.7750 - val_loss: 0.5825 - val_accuracy: 0.6947 - val_auc: 0.7629
# Epoch 23/50
# 3125/3125 - 8s - loss: 0.5655 - accuracy: 0.7040 - auc: 0.7769 - val_loss: 0.5876 - val_accuracy: 0.6863 - val_auc: 0.7575
# Epoch 24/50
# 3125/3125 - 8s - loss: 0.5642 - accuracy: 0.7061 - auc: 0.7781 - val_loss: 0.5789 - val_accuracy: 0.6935 - val_auc: 0.7647
# Epoch 25/50
# 3125/3125 - 6s - loss: 0.5632 - accuracy: 0.7066 - auc: 0.7788 - val_loss: 0.5845 - val_accuracy: 0.6938 - val_auc: 0.7647
# Epoch 26/50
# 3125/3125 - 8s - loss: 0.5622 - accuracy: 0.7081 - auc: 0.7802 - val_loss: 0.5789 - val_accuracy: 0.6932 - val_auc: 0.7665
# Epoch 27/50
# 3125/3125 - 8s - loss: 0.5608 - accuracy: 0.7087 - auc: 0.7815 - val_loss: 0.5942 - val_accuracy: 0.6795 - val_auc: 0.7670
# Epoch 28/50
# 3125/3125 - 8s - loss: 0.5599 - accuracy: 0.7080 - auc: 0.7820 - val_loss: 0.5770 - val_accuracy: 0.6942 - val_auc: 0.7679
# Epoch 29/50
# 3125/3125 - 6s - loss: 0.5580 - accuracy: 0.7118 - auc: 0.7842 - val_loss: 0.5768 - val_accuracy: 0.6967 - val_auc: 0.7659
# Epoch 30/50
# 3125/3125 - 6s - loss: 0.5581 - accuracy: 0.7109 - auc: 0.7843 - val_loss: 0.5811 - val_accuracy: 0.6913 - val_auc: 0.7674
# Epoch 31/50
# 3125/3125 - 8s - loss: 0.5570 - accuracy: 0.7105 - auc: 0.7851 - val_loss: 0.5784 - val_accuracy: 0.6970 - val_auc: 0.7667
# Epoch 32/50
# 3125/3125 - 8s - loss: 0.5562 - accuracy: 0.7117 - auc: 0.7862 - val_loss: 0.5776 - val_accuracy: 0.6954 - val_auc: 0.7673
# Epoch 33/50
# 3125/3125 - 6s - loss: 0.5543 - accuracy: 0.7118 - auc: 0.7874 - val_loss: 0.5729 - val_accuracy: 0.7006 - val_auc: 0.7695
# Epoch 34/50
# 3125/3125 - 6s - loss: 0.5540 - accuracy: 0.7136 - auc: 0.7879 - val_loss: 0.5782 - val_accuracy: 0.6986 - val_auc: 0.7700
# Epoch 35/50
# 3125/3125 - 8s - loss: 0.5526 - accuracy: 0.7143 - auc: 0.7894 - val_loss: 0.5749 - val_accuracy: 0.6977 - val_auc: 0.7690
# Epoch 36/50
# 3125/3125 - 6s - loss: 0.5510 - accuracy: 0.7158 - auc: 0.7908 - val_loss: 0.5824 - val_accuracy: 0.6928 - val_auc: 0.7613
# Epoch 37/50
# 3125/3125 - 6s - loss: 0.5510 - accuracy: 0.7150 - auc: 0.7906 - val_loss: 0.5821 - val_accuracy: 0.6920 - val_auc: 0.7643
# Epoch 38/50
# 3125/3125 - 6s - loss: 0.5500 - accuracy: 0.7161 - auc: 0.7916 - val_loss: 0.5804 - val_accuracy: 0.6971 - val_auc: 0.7683
# Epoch 39/50
# 3125/3125 - 8s - loss: 0.5491 - accuracy: 0.7171 - auc: 0.7926 - val_loss: 0.5739 - val_accuracy: 0.6999 - val_auc: 0.7687
# Epoch 40/50
# 3125/3125 - 6s - loss: 0.5485 - accuracy: 0.7192 - auc: 0.7934 - val_loss: 0.5789 - val_accuracy: 0.6943 - val_auc: 0.7678
# Epoch 41/50
# 3125/3125 - 6s - loss: 0.5468 - accuracy: 0.7191 - auc: 0.7949 - val_loss: 0.5718 - val_accuracy: 0.7006 - val_auc: 0.7731
# Epoch 42/50
# 3125/3125 - 6s - loss: 0.5462 - accuracy: 0.7206 - auc: 0.7954 - val_loss: 0.5735 - val_accuracy: 0.7007 - val_auc: 0.7705
# Epoch 43/50
# 3125/3125 - 8s - loss: 0.5462 - accuracy: 0.7212 - auc: 0.7955 - val_loss: 0.5885 - val_accuracy: 0.6909 - val_auc: 0.7656
# Epoch 44/50
# 3125/3125 - 8s - loss: 0.5449 - accuracy: 0.7199 - auc: 0.7967 - val_loss: 0.5818 - val_accuracy: 0.6967 - val_auc: 0.7651
# Epoch 45/50
# 3125/3125 - 6s - loss: 0.5441 - accuracy: 0.7225 - auc: 0.7975 - val_loss: 0.5753 - val_accuracy: 0.7002 - val_auc: 0.7706
# Epoch 46/50
# 3125/3125 - 8s - loss: 0.5441 - accuracy: 0.7214 - auc: 0.7975 - val_loss: 0.5814 - val_accuracy: 0.6981 - val_auc: 0.7705
# Epoch 47/50
# 3125/3125 - 6s - loss: 0.5428 - accuracy: 0.7221 - auc: 0.7985 - val_loss: 0.5996 - val_accuracy: 0.6880 - val_auc: 0.7699
# Epoch 48/50
# 3125/3125 - 8s - loss: 0.5421 - accuracy: 0.7230 - auc: 0.7991 - val_loss: 0.5859 - val_accuracy: 0.6885 - val_auc: 0.7718
# Epoch 49/50
# 3125/3125 - 8s - loss: 0.5415 - accuracy: 0.7238 - auc: 0.7995 - val_loss: 0.5739 - val_accuracy: 0.7020 - val_auc: 0.7707
# Epoch 50/50
# 3125/3125 - 6s - loss: 0.5415 - accuracy: 0.7241 - auc: 0.7996 - val_loss: 0.5988 - val_accuracy: 0.6899 - val_auc: 0.7650

# %%
plt.figure(figsize=(20, 8), facecolor="white")
ax1=plt.subplot(1, 2, 1)
plt.plot(history.history["loss"], label="training loss")
plt.plot(history.history["val_loss"], label="validation loss")
plt.legend()
ax1.set_ylim([0.4,0.7])
plt.title("Training and testing loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
ax2=plt.subplot(1, 2, 2)
plt.plot(history.history["auc"], label="training AUC")
plt.plot(history.history["val_auc"], label="validation AUC")
plt.legend()
ax2.set_ylim([0.5,0.8])
plt.title("Training and testing AUC")
plt.xlabel("Epochs")
plt.ylabel("AUC")
# Out:
# Text(0, 0.5, 'AUC')

# %%
tf.keras.utils.plot_model(model, "my_first_model.png")

# %%
model.summary()
model.evaluate(x_test,y_test,verbose=1)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 256)               7424
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 7,681
# Trainable params: 7,681
# Non-trainable params: 0
# _________________________________________________________________
# 3125/3125 [==============================] - 4s 1ms/step - loss: 0.5979 - accuracy: 0.6923 - auc: 0.7668
# [0.597893476486206, 0.6922900080680847, 0.7668190598487854]
